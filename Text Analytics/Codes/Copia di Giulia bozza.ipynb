# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import urllib.request
import os

def download_file(url,local_file, force=False):
    """
    Helper function to download a file and store it locally
    """
    if not os.path.exists(local_file) or force:
        print('Downloading',url,'to',local_file)
        with urllib.request.urlopen(url) as opener, \
             open(local_file, mode='w', encoding='utf-8') as outfile:
                    outfile.write(opener.read().decode('utf-8'))
    else:
        print(local_file,'already downloaded')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# We delete duplicates rows from the files
with open("drive/MyDrive/Text Analytics/Sentences_AllAgree.txt",encoding = "ISO-8859-1",newline='') as f:
    with open("drive/MyDrive/Text Analytics/Sentences_AllAgreeClean.txt", "w") as output: 
      seen = set()
      for line in f:
          line_lower = line.lower()
          if line_lower in seen:
              print(line)
          else:
            seen.add(line_lower)
            output.write(line_lower)
with open("drive/MyDrive/Text Analytics/Sentences_50Agree.txt",encoding = "ISO-8859-1",newline='') as f:
    with open("drive/MyDrive/Text Analytics/Sentences_50AgreeClean.txt", "w") as output: 
      seen = set()
      for line in f:
          line_lower = line.lower()
          if line_lower in seen:
              print(line)
          else:
            seen.add(line_lower)
            output.write(line_lower)
# Out:
# The issuer is solely responsible for the content of this announcement .@neutral
#
# The report profiles 614 companies including many key and niche players worldwide such as Black & Decker Corporation , Fiskars Corporation , Fiskars Brands , Inc. , Husqvarna Outdoor Products Inc. , K+S Group , Ryobi Technologies , Inc. , The Scotts Miracle-Gro Company , and Van Group , Inc. .@neutral
#
# Ahlstrom 's share is quoted on the NASDAQ OMX Helsinki .@neutral
#
# SSH Communications Security Corporation is headquartered in Helsinki , Finland .@neutral
#
# The company serves customers in various industries , including process and resources , industrial machinery , architecture , building , construction , electrical , transportation , electronics , chemical , petrochemical , energy , and information technology , as well as catering and households .@neutral
#
# The issuer is solely responsible for the content of this announcement .@neutral
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from difflib import Differ
  
with open("drive/MyDrive/Text Analytics/Sentences_AllAgree.txt",encoding = "ISO-8859-1",newline='') as file_1, open("drive/MyDrive/Text Analytics/Sentences_50Agree.txt",encoding = "ISO-8859-1",newline='') as file_2:
    differ = Differ()
    with open("drive/MyDrive/Text Analytics/Sentences_AgreeNotCommon.txt", "w") as output: 
      for line in differ.compare(file_1.readlines(), file_2.readlines()):
         output.write(line)

# %%
# Merge the 2 files into one and run the previous code
with open("drive/MyDrive/Text Analytics/Sentences_AllAgree.txt",encoding = "ISO-8859-1",newline='') as file_1,\
                    open("drive/MyDrive/Text Analytics/Sentences_50Agree.txt",encoding = "ISO-8859-1",newline='') as file_2:
                    with open("drive/MyDrive/Text Analytics/Sentences_Merge.txt", "w") as output: 
                      for line in file_2:
                        seen = [i.replace('\r','') for i in seen]
                        seen = [i.replace('\n','') for i in seen]
                        for i in seen:
                          for line1 in file_1:
                            #line_lower1 = line1.lower()
                            if line != line1:
                              output.write(line1)
                            else:
                              break                                   
            
file_1.close()
file_2.close()

# %%
train_file="drive/MyDrive/Text Analytics/Sentences_AllAgree.txt"

import csv
delimiter="@"
x_train_all = list()
y_train_all = list()
with open(train_file,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_all.append(row[0])
            y_train_all.append(row[1])

# %%
len(x_train_all),len(y_train_all)
# Out:
# (2264, 2264)

# %%
train_file_75="drive/MyDrive/Text Analytics/Sentences_75Agree.txt"
delimiter="@"
x_train_75 = list()
y_train_75 = list()
with open(train_file_75,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_75.append(row[0])
            y_train_75.append(row[1])

len(x_train_75),len(y_train_75)
# Out:
# (3453, 3453)

# %%
train_file_66="drive/MyDrive/Text Analytics/Sentences_66Agree.txt"
delimiter="@"
x_train_66 = list()
y_train_66 = list()
with open(train_file_66,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_66.append(row[0])
            y_train_66.append(row[1])

len(x_train_66),len(y_train_66)
# Out:
# (4217, 4217)

# %%
train_file_50="drive/MyDrive/Text Analytics/Sentences_50Agree.txt"
delimiter="@"
x_train_50 = list()
y_train_50 = list()
with open(train_file_50,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_50.append(row[0])
            y_train_50.append(row[1])

len(x_train_50),len(y_train_50)
# Out:
# (4846, 4846)

# %%
df = pd.read_csv('drive/MyDrive/Text Analytics/all-data.csv', encoding = "ISO-8859-1")

# %%
df.head
# Out:
# <bound method NDFrame.head of        neutral According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 0      neutral  Technopolis plans to develop in stages an area...
# 1     negative  The international electronic industry company ...
# 2     positive  With the new production plant the company woul...
# 3     positive  According to the company 's updated strategy f...
# 4     positive  FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...
# ...        ...                                                ...
# 4840  negative  LONDON MarketWatch -- Share prices ended lower...
# 4841   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4842  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4843  negative  Net sales of the Paper segment decreased to EU...
# 4844  negative  Sales in Finland decreased by 10.5 % in Januar...
#
# [4845 rows x 2 columns]>

# %%
df = pd.read_csv("drive/MyDrive/Text Analytics/Sentences_Merge.txt",encoding = "ISO-8859-1",header=None,sep='@')

# %%
df
# Out:
#                                                       0         1
# 0     For the last quarter of 2010 , Componenta 's n...  positive
# 1     In the third quarter of 2010 , net sales incre...  positive
# 2     Operating profit rose to EUR 13.1 mn from EUR ...  positive
# 3     Operating profit totalled EUR 21.1 mn , up fro...  positive
# 4     Finnish Talentum reports its operating profit ...  positive
# ...                                                 ...       ...
# 2258  Operating result for the 12-month period decre...  negative
# 2259  HELSINKI Thomson Financial - Shares in Cargote...  negative
# 2260  LONDON MarketWatch -- Share prices ended lower...  negative
# 2261  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 2262  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [2263 rows x 2 columns]

# %%
df_1 = pd.read_csv("drive/MyDrive/Text Analytics/Sentences_AllAgree.txt", encoding = "ISO-8859-1",header=None,sep='@')

# %%
df_1
# Out:
#                                                       0         1
# 0     According to Gran , the company has no plans t...   neutral
# 1     For the last quarter of 2010 , Componenta 's n...  positive
# 2     In the third quarter of 2010 , net sales incre...  positive
# 3     Operating profit rose to EUR 13.1 mn from EUR ...  positive
# 4     Operating profit totalled EUR 21.1 mn , up fro...  positive
# ...                                                 ...       ...
# 2259  Operating result for the 12-month period decre...  negative
# 2260  HELSINKI Thomson Financial - Shares in Cargote...  negative
# 2261  LONDON MarketWatch -- Share prices ended lower...  negative
# 2262  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 2263  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [2264 rows x 2 columns]

# %%
df_2 = pd.read_csv("drive/MyDrive/Text Analytics/Sentences_50Agree.txt", encoding = "ISO-8859-1",header=None,sep='@')

# %%
df_2
# Out:
#                                                       0         1
# 0     According to Gran , the company has no plans t...   neutral
# 1     Technopolis plans to develop in stages an area...   neutral
# 2     The international electronic industry company ...  negative
# 3     With the new production plant the company woul...  positive
# 4     According to the company 's updated strategy f...  positive
# ...                                                 ...       ...
# 4841  LONDON MarketWatch -- Share prices ended lower...  negative
# 4842  Rinkuskiai 's beer sales fell by 6.5 per cent ...   neutral
# 4843  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 4844  Net sales of the Paper segment decreased to EU...  negative
# 4845  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [4846 rows x 2 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from string import punctuation
from wordcloud import WordCloud
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords, wordnet
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
import plotly.express as px
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
def read_data():
    dataset=pd.read_csv("drive/MyDrive/Text Analytics/Sentences_Merge.txt", sep='@',
                header=None,
                 names=['News','Sentiment'],
                 encoding = "ISO-8859-1")
    return dataset

def convert_to_lower_case():
    def lower(input_text):
        return input_text.lower()
    df['News']=df['News'].apply(lower)
    
def remove_punctuation():
    def remove_punctuation_from_text(input_text):
        output_list=[word for word in input_text.split() if word.isalpha()]
        return ' '.join(output_list)    
    df['News']=df['News'].apply(remove_punctuation_from_text)
    
def correct_words():
    def correct_text(input_text):
        list_1=[str(TextBlob(word).correct()) for word in input_text.split()]
        output_text= ' '.join(list_1)
        return output_text
    df['News']=df['News'].apply(correct_text)
    
def lemmatize():
    def lematize_text(input_text):
        doc=nlp(input_text)
        lemmas=[token.lemma_ for token in doc]
        output_text=' '.join(lemmas)
        return output_text
    df['News']=df['News'].apply(lematize_text)
    
def remove_stopwords():
    def remove_stopwords_from_text(input_text):
        stopwords=spacy.lang.en.stop_words.STOP_WORDS
        output_list=[word for word in input_text.split() if word not in stopwords and not(word=='-PRON-') ]
        return ' '.join(output_list)
    df['News']=df['News'].apply(remove_stopwords_from_text)

def filter_the_neutral_news():
    return df[df['Sentiment']!='neutral']

def create_target_and_input():
    target=df['Sentiment'].values.tolist()
    target=[1 if sentiment=='positive' else 0 for sentiment in target]
    data=df['News'].values.tolist()
    return data,target

def split_train_test():
    x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42,stratify=target)
    y_train=np.array(y_train)
    y_test=np.array(y_test)
    return x_train, x_test, y_train, y_test

# %%
df = read_data()
#convert_to_lower_case()
#remove_punctuation()
#lemmatize()
#remove_stopwords()

# %%
df
# Out:
#                                                    News Sentiment
# 0     For the last quarter of 2010 , Componenta 's n...  positive
# 1     In the third quarter of 2010 , net sales incre...  positive
# 2     Operating profit rose to EUR 13.1 mn from EUR ...  positive
# 3     Operating profit totalled EUR 21.1 mn , up fro...  positive
# 4     Finnish Talentum reports its operating profit ...  positive
# ...                                                 ...       ...
# 2258  Operating result for the 12-month period decre...  negative
# 2259  HELSINKI Thomson Financial - Shares in Cargote...  negative
# 2260  LONDON MarketWatch -- Share prices ended lower...  negative
# 2261  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 2262  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [2263 rows x 2 columns]

# %%
#dopo la pulizia il dataset risulta avere la stessa composizone (più o meno) del dataset originale
sns.countplot(y="Sentiment",data=df)

# %%
Y_count = len(df[df['Sentiment'] == 'negative'])
N_count = len(df[df['Sentiment'] == 'positive'])
Z_count = len(df[df['Sentiment'] == 'neutral'])

# create data
names='negative', 'positive','neutral',
size=[Y_count,N_count,Z_count]

# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['lightcoral','cornflowerblue','green'],autopct='%1.0f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
ax = plt.axes()
ax.set_title("Sentiment Proportion")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
def read_data_1():
    dataset= pd.read_csv("drive/MyDrive/Text Analytics/Sentences_AllAgree.txt", sep='@',
                header=None,
                 names=['News','Sentiment'],
                 encoding = "ISO-8859-1")
    return dataset

# %%
df_1= read_data_1()

# %%
df_1
# Out:
#                                                    News Sentiment
# 0     According to Gran , the company has no plans t...   neutral
# 1     For the last quarter of 2010 , Componenta 's n...  positive
# 2     In the third quarter of 2010 , net sales incre...  positive
# 3     Operating profit rose to EUR 13.1 mn from EUR ...  positive
# 4     Operating profit totalled EUR 21.1 mn , up fro...  positive
# ...                                                 ...       ...
# 2259  Operating result for the 12-month period decre...  negative
# 2260  HELSINKI Thomson Financial - Shares in Cargote...  negative
# 2261  LONDON MarketWatch -- Share prices ended lower...  negative
# 2262  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 2263  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [2264 rows x 2 columns]

# %%
#controllare la composizione del dataset all agree
sns.countplot(y="Sentiment",data=df_1)

# %%
Y_count = len(df_1[df_1['Sentiment'] == 'negative'])
N_count = len(df_1[df_1['Sentiment'] == 'positive'])
Z_count = len(df_1[df_1['Sentiment'] == 'neutral'])

# create data
names='negative', 'positive','neutral',
size=[Y_count,N_count,Z_count]

# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['lightcoral','cornflowerblue','green'],autopct='%1.0f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
ax = plt.axes()
ax.set_title("Sentiment Proportion")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
def read_data_2():
    dataset= pd.read_csv("drive/MyDrive/Text Analytics/Sentences_75Agree.txt", sep='@',
                header=None,
                 names=['News','Sentiment'],
                 encoding = "ISO-8859-1")
    return dataset

# %%
df_2 = read_data_2()

# %%
df_2
# Out:
#                                                    News Sentiment
# 0     According to Gran , the company has no plans t...   neutral
# 1     With the new production plant the company woul...  positive
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     In the third quarter of 2010 , net sales incre...  positive
# 4     Operating profit rose to EUR 13.1 mn from EUR ...  positive
# ...                                                 ...       ...
# 3448  Operating result for the 12-month period decre...  negative
# 3449  HELSINKI Thomson Financial - Shares in Cargote...  negative
# 3450  LONDON MarketWatch -- Share prices ended lower...  negative
# 3451  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 3452  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [3453 rows x 2 columns]

# %%
sns.countplot(y="Sentiment",data=df_2)

# %%
Y_count = len(df_2[df_2['Sentiment'] == 'negative'])
N_count = len(df_2[df_2['Sentiment'] == 'positive'])
Z_count = len(df_2[df_2['Sentiment'] == 'neutral'])

# create data
names='negative', 'positive','neutral',
size=[Y_count,N_count,Z_count]

# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['lightcoral','cornflowerblue','green'],autopct='%1.0f%%')
p=plt.gcf()
p.gca().add_artist(my_circle)
ax = plt.axes()
ax.set_title("Sentiment Proportion")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
#
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
stop = set(stopwords.words('english'))
stop.update(punctuation)
print(stop)
# Out:
# {'couldn', "you'll", 'before', 'over', 'for', "didn't", 'my', 'few', 'when', "wouldn't", 'below', "aren't", "you'd", 'out', 'ours', 'have', '_', 'at', 'has', '#', 'him', "you've", 'which', 'more', 'is', 'a', 'don', 'now', 'on', 'didn', 'needn', "hadn't", ',', 'hadn', "haven't", 'that', "shan't", 'doesn', '-', '~', 'nor', 'i', 'm', 'theirs', "won't", 'ourselves', '%', 'all', 'than', 'should', 'won', '.', 'against', 'such', "doesn't", 'being', '[', 'having', 'had', 'whom', 'you', 'was', 'into', 'further', 'where', 'our', '=', '!', 'do', 'wouldn', 'very', 'o', 'them', "couldn't", 'until', '&', ';', '$', "she's", '>', 'but', 'mustn', "you're", 'they', 'during', 'again', 'about', 're', 'wasn', "mightn't", 'shouldn', 'doing', 'am', 'myself', 'does', 'these', "needn't", '\\', 've', 'some', 'herself', 'as', 'most', 'the', "shouldn't", '/', 'an', 'any', 'both', '@', 'other', 's', 'yourself', "hasn't", 'to', 'y', 'yours', 'weren', 'of', 'only', "don't", 'what', 'haven', "mustn't", "'", 'down',
# ...

# %%
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
lemmatizer = WordNetLemmatizer()
def clean_review(text):
    clean_text = []
    for w in word_tokenize(text):
        if w.lower() not in stop:
            pos = pos_tag([w])
            new_w = lemmatizer.lemmatize(w, pos=get_simple_pos(pos[0][1]))
            clean_text.append(new_w)
    return clean_text

def join_text(text):
    return " ".join(text)

# %%
df_1.News = df_1.News.apply(clean_review)
df_1.News = df_1.News.apply(join_text)

# %%
df_1
# Out:
# 0       According Gran company plan move production Ru...
# 1       last quarter 2010 Componenta 's net sale doubl...
# 2       third quarter 2010 net sale increase 5.2 EUR 2...
# 3       Operating profit rise EUR 13.1 mn EUR 8.7 mn c...
# 4       Operating profit total EUR 21.1 mn EUR 18.6 mn...
#                               ...
# 2259    Operating result 12-month period decrease prof...
# 2260    HELSINKI Thomson Financial Shares Cargotec fel...
# 2261    LONDON MarketWatch -- Share price end low Lond...
# 2262    Operating profit fell EUR 35.4 mn EUR 68.8 mn ...
# 2263    Sales Finland decrease 10.5 January sale outsi...
# Name: News, Length: 2264, dtype: object
