# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import urllib.request
import os

def download_file(url,local_file, force=False):
    """
    Helper function to download a file and store it locally
    """
    if not os.path.exists(local_file) or force:
        print('Downloading',url,'to',local_file)
        with urllib.request.urlopen(url) as opener, \
             open(local_file, mode='w', encoding='utf-8') as outfile:
                    outfile.write(opener.read().decode('utf-8'))
    else:
        print(local_file,'already downloaded')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_file="/Users/giuli/Desktop/Text analytics/archive/FinancialPhraseBank/Sentences_AllAgree.txt"

import csv
delimiter="@"
x_train_all = list()
y_train_all = list()
with open(train_file,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_all.append(row[0])
            y_train_all.append(row[1])

# %%
len(x_train_all),len(y_train_all)
# Out:
# (2264, 2264)

# %%
train_file_75="/Users/giuli/Desktop/Text analytics/archive/FinancialPhraseBank/Sentences_75Agree.txt"
delimiter="@"
x_train_75 = list()
y_train_75 = list()
with open(train_file_75,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_75.append(row[0])
            y_train_75.append(row[1])

len(x_train_75),len(y_train_75)
# Out:
# (3453, 3453)

# %%
train_file_66="/Users/giuli/Desktop/Text analytics/archive/FinancialPhraseBank/Sentences_66Agree.txt"
delimiter="@"
x_train_66 = list()
y_train_66 = list()
with open(train_file_66,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_66.append(row[0])
            y_train_66.append(row[1])

len(x_train_66),len(y_train_66)
# Out:
# (4217, 4217)

# %%
train_file_50="/Users/giuli/Desktop/Text analytics/archive/FinancialPhraseBank/Sentences_50Agree.txt"
delimiter="@"
x_train_50 = list()
y_train_50 = list()
with open(train_file_50,encoding = "ISO-8859-1",newline='') as infile:
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        if row:
            x_train_50.append(row[0])
            y_train_50.append(row[1])

len(x_train_50),len(y_train_50)
# Out:
# (4846, 4846)

# %%
df = pd.read_csv('//Users/giuli/Desktop/Text analytics/archive/all-data.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of        neutral  \
# 0      neutral
# 1     negative
# 2     positive
# 3     positive
# 4     positive
# ...        ...
# 4840  negative
# 4841   neutral
# 4842  negative
# 4843  negative
# 4844  negative
#
#      According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .
# 0     Technopolis plans to develop in stages an area...
# 1     The international electronic industry company ...
# 2     With the new production plant the company woul...
# 3     According to the company 's updated strategy f...
# 4     FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...
# ...                                                 ...
# 4840  LONDON MarketWatch -- Share prices ended lower...
# 4841  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4842  Operating profit fell to EUR 35.4 mn from EUR ...
# 4843  Net sales of the Paper segment decreased to EU...
# ...
