# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
train_file = 'drive/MyDrive/Text Analytics/Dati/archive/FinancialPhraseBank/without_test_50Agree.txt'
test_file = 'drive/MyDrive/Text Analytics/Dati/archive/FinancialPhraseBank/test_set_binary.txt'
delimiter = ','

# %%
import csv
review_train = list()
label_train = list()
with open(train_file, encoding='utf-8', newline='') as infile:
    next(infile)
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        review_train.append(row[1])
        label_train.append(row[0])

review_test = list()
label_test = list()
with open(test_file, encoding='utf-8', newline='') as infile:
    next(infile)
    reader = csv.reader(infile, delimiter=delimiter)
    for row in reader:
        review_test.append(row[1])
        label_test.append(row[0])

# %%
review_train[1]
# Out:
# 'technopolis plan develop stage area le 100000 square meter order host company working computer technology telecommunication statement said'

# %%
from string import punctuation
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
all_text = ''.join([c for c in review_train if c not in punctuation])

# %%
all_text
# Out:
# 'according gran company plan move production russia although company growingtechnopolis plan develop stage area le 100000 square meter order host company working computer technology telecommunication statement saidinternational electronic industry company elcoteq laid ten employee tallinn facility contrary earlier layoff company contracted rank office worker daily postimees reportednew production plant company would increase capacity meet expected increase demand would improve use raw material therefore increase production profitabilityaccording company updated strategy year 20092012 basware target longterm net sale growth range 20 40 operating profit margin 10 20 net salefinancing aspocomp growth aspocomp aggressively pursuing growth strategy increasingly focusing technologically demanding hdi printed circuit board pcbsoperating profit rose eur 131 mn eur 87 mn corresponding period 2007 representing 77 net saleoperating profit totalled eur 211 mn eur 186 mn 2007 representing 97 net saleteliasonera tlsn said offer line strategy increase ownership core business holding would strengthen eesti telekom offering customerpurchase agreement 7200 ton gasoline delivery hamina terminal finland signed neste oil oyj average platts index september plus eight u dollar per monthclothing retail chain seppñlñ sale increased 8 eur 1552 mn operating profit rose eur 311 mn eur 171 mn 2004foundry division report sale increased 97 eur 631 mn eur 575 mn corresponding period 2006 sale machine shop division increased 164 eur 412 mn eur 354 mn corresponding period 2006incap contract manufacturing service pvt ltd subsidiary incap corporation finland plan double revenue 20072008board director propose dividend eur0 12 per share 2010 eur0 08 per share paid 2009lifetree founded 2000 revenue risen average 40 margin late 30megafon subscriber base increased 161 2009 505 million user december 31 market share number customer amounted 24 late 2009 23 late 2008 according teliasonera estimatenet income life insurance doubled eur 68 mn eur 32 mn net income nonlife insurance rose eur 52 mn eur 15 mn corresponding period 2009net sale increased eur193 3 eur179 9 pretax profit rose 342 eur43 1 eur1 usd1 4net sale surged 185 eur167 8 teleste said eur20 4 122 sale came acquisition made 2009nordea group operating profit increased 2010 18 percent yearonyear 364 billion euro total revenue 3 percent 933 billion eurooperating profit ninemonth period increased eur3 1 net sale increased eur61 5 compared corresponding period 2007operating profit threemonth period increased eur1 2 revenue increased eur20 2 compared corresponding period 2005lithuanian beer market made 1441 million liter january rise 08 percent yearearlier figure lithuanian brewer association reporting citing result memberfair value property portfolio doubled result kapiteeli acquisition totalled eur 26862 12597 million10 february 2011 finnish medium company sanoma oyj hel saa1v said yesterday 2010 net profit almost tripled eur297 3 eur107 1 2009 announced proposal raised payouthelsinki eliiv today reported eps eur1 13 2009 increase eps eur1 12 2008aspo plc stock exchange release february 11 2011 at8 45 esl shipping ltd part aspo group signed new longterm contract rautaruukki corporation marine transport raw material baltic seacommission income increased 22 eur 44 mn lending volume rose 135january traffic measured revenue passenger kilometre rpk went 32 capacity measured available seat kilometre ask rose 122net income life insurance rose eur 165 mn eur 140 mn net income nonlife insurance eur 226 mn eur 152 mn 2009nyrstar also agreed supply talvivaara 150000 tonne sulphuric acid per annum use talvivaara leaching process period supply zinc concentratesale department store division hobby hall increased 7 sale clothing store subsidiary seppala decreased 4sale risen export marketsale increased due growing market rate increased operationcompany also estimate already carried investment lead increase net sale 2010 2009 reac ...

# %%
reviews_split = all_text.split('\n')
print ('Number of reviews :', len(reviews_split))
# Out:
# Number of reviews : 1
